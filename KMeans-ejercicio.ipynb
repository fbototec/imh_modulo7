# %% [markdown]
# # Ejercicio: Aplicación de k-Means al Iris dataset

# %% [markdown]
# ## Importat los modulos necesarios

# %%
from sklearn import datasets, cluster, metrics
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# note: deliberately chose a random seed that ends up 
# labeling the clusters with the same numbering convention 
# as the original y values 
np.random.seed(2)

# %% [markdown]
# ## 1. Cargar el Iris dadaset en el notebook

# %%
# load data
# iris =

# %% [markdown]
# ## 2. Separar el dataset en características (X) y la variable objetivo (y)

# %%
# get X and y 
# X_iris = 
# y_iris =

# %% [markdown]
# ## 3. Inicializar el modelo k-means con 3 clusters

# %%
# k_means_model =

# %% [markdown]
# ## Ajustar el modelo

# %% [markdown]
# ## 5. Accede a las etiquetas de los clusters

# %%
# labels =

# %% [markdown]
# ## 6. Revisa cuántas ejemplos han sido correctamente etiquetados

# %% [markdown]
# ## 7. Calcula el Adjusted Rand index

# %% [markdown]
# ## 8. Crea una figura con los clusters en color aproximada a la de la figura
#
# ![image.png](attachment:image.png)
#
# Los 3 ejes corresponden a tres de las variables del data set y el color al cluster asignado

# %%
# TIP: usa la función Axes3D

# %% [markdown]
# ## 9. Calcula el coeficiente silhouette

# %% [markdown]
# ## 10. Es correcta la clasificación? Sabes qué cluster es cada clase? Intenta obtener una medida más fiable del error
